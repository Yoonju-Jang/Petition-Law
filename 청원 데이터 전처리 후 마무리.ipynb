# %%
import pandas as pd
petition = pd.read_csv("C:/Users/82109/Documents/Jupyter/final_petition.csv")
petition
# Out:
#         category                                              title  votes  \
# 0            일자리                                 공정한 기회 균등이 보장되는 사회    144
# 1            일자리                              영어회화전문강사제도는 유지되어야합니다.   1185
# 2            일자리                           공공기관 무조건적인 정규직전환을 반대합니다.     53
# 3           보건복지  보건복지부 부령 제339호중 “특수의료장비 운영에 관한 규칙” 중  불합리한 행정제...      2
# 4          경제민주화                                      소액주주를 보호해주십시오   2137
# ...          ...                                                ...    ...
# 437531        기타                                    화물연대의 갑질을 막아주세요    413
# 437532  외교/통일/국방                              해병대 훈련소에서 쫒겨난 훈련병 이야기    213
# 437533    인권/성평등  가슴에 물혹이 40개 있습니다. 아픈몸으로 성추행을 당했고 상간녀누명을 씌운 성추행...   2129
# 437534        행정                       실내외 마스크 착용 의무화를 해제할 것을 촉구합니다   2086
# 437535      보건복지                    코로나와 백신에 대한 정확한진실과 정직한언론을 촉구합니다    387
#
#           end date
# 0       2017-08-26
# 1       2017-08-26
# ...

# %%
over_petition = petition[petition['votes']>10]
over_petition
# Out:
#         category                                              title  votes  \
# 0            일자리                                 공정한 기회 균등이 보장되는 사회    144
# 1            일자리                              영어회화전문강사제도는 유지되어야합니다.   1185
# 2            일자리                           공공기관 무조건적인 정규직전환을 반대합니다.     53
# 4          경제민주화                                      소액주주를 보호해주십시오   2137
# 7            일자리                              영어회화전문강사제도는 유지되어야합니다.     17
# ...          ...                                                ...    ...
# 437531        기타                                    화물연대의 갑질을 막아주세요    413
# 437532  외교/통일/국방                              해병대 훈련소에서 쫒겨난 훈련병 이야기    213
# 437533    인권/성평등  가슴에 물혹이 40개 있습니다. 아픈몸으로 성추행을 당했고 상간녀누명을 씌운 성추행...   2129
# 437534        행정                       실내외 마스크 착용 의무화를 해제할 것을 촉구합니다   2086
# 437535      보건복지                    코로나와 백신에 대한 정확한진실과 정직한언론을 촉구합니다    387
#
#           end date
# 0       2017-08-26
# 1       2017-08-26
# ...

# %%
over_petition.to_csv('./finish_petition.csv', index = None)
