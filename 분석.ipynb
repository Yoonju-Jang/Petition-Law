# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# # 입법

# %%
import pandas as pd
import numpy as np
law = pd.read_csv("C:/Users/82109/Documents/GitHub/cla3109_project/congress_law_crawling.csv")
# 데이터의 크기가 어느정도인지 본다.
law.shape
# Out:
# (30540, 8)

# %%
law
# Out:
#                                 CONTENT INITIATION DATE RELEVANT DEPARTMENT  \
# 0                           국회법 일부개정법률안       2022.5.6.                 법제처
# 1                         정부조직법 일부개정법률안       2022.5.6.               행정안전부
# 2            스토킹범죄의 처벌 등에 관한 법률 일부개정법률안       2022.5.6.                 법무부
# 3                         지방자치법 일부개정법률안       2022.5.6.               행정안전부
# 4                대통령직 인수에 관한 법률 일부개정법률안       2022.5.6.               행정안전부
# ...                                 ...             ...                 ...
# 30535                     식품위생법 일부개정법률안      2017.8.21.            식품의약품안전처
# 30536             의료기사 등에 관한 법률 일부개정법률안      2017.8.21.               보건복지부
# 30537    농어촌주민의 보건복지 증진을 위한 특별법 일부개정법률안      2017.8.21.               보건복지부
# 30538  사회서비스 이용 및 이용권 관리에 관한 법률 일부개정법률안      2017.8.21.               보건복지부
# 30539                     전기사업법 일부개정법률안      2017.8.21.             산업통상자원부
#
#       CATEGORY  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0         정치개혁         NaN         NaN         NaN         NaN
# 1           행정         NaN         NaN         NaN         NaN
# 2         정치개혁         NaN         NaN         NaN         NaN
# 3           행정         NaN         NaN         NaN         NaN
# 4           행정         NaN         NaN         NaN         NaN
# ...        ...         ...         ...         ...         ...
# 30535    안전/환경         NaN         NaN         NaN         NaN
# 30536     보건복지         NaN         NaN         NaN         NaN
# 30537     보건복지         NaN         NaN         NaN         NaN
# 30538     보건복지         NaN         NaN         NaN         NaN
# 30539     성장동력         NaN         NaN         NaN         NaN
#
# [30540 rows x 8 columns]

# %%
law.columns
# Out:
# Index(['CONTENT', 'INITIATION DATE', 'RELEVANT DEPARTMENT', 'CATEGORY',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
laws = law[['CONTENT','INITIATION DATE','RELEVANT DEPARTMENT','CATEGORY']]
laws
# Out:
#                                 CONTENT INITIATION DATE RELEVANT DEPARTMENT  \
# 0                           국회법 일부개정법률안       2022.5.6.                 법제처
# 1                         정부조직법 일부개정법률안       2022.5.6.               행정안전부
# 2            스토킹범죄의 처벌 등에 관한 법률 일부개정법률안       2022.5.6.                 법무부
# 3                         지방자치법 일부개정법률안       2022.5.6.               행정안전부
# 4                대통령직 인수에 관한 법률 일부개정법률안       2022.5.6.               행정안전부
# ...                                 ...             ...                 ...
# 30535                     식품위생법 일부개정법률안      2017.8.21.            식품의약품안전처
# 30536             의료기사 등에 관한 법률 일부개정법률안      2017.8.21.               보건복지부
# 30537    농어촌주민의 보건복지 증진을 위한 특별법 일부개정법률안      2017.8.21.               보건복지부
# 30538  사회서비스 이용 및 이용권 관리에 관한 법률 일부개정법률안      2017.8.21.               보건복지부
# 30539                     전기사업법 일부개정법률안      2017.8.21.             산업통상자원부
#
#       CATEGORY
# 0         정치개혁
# 1           행정
# 2         정치개혁
# 3           행정
# 4           행정
# ...        ...
# 30535    안전/환경
# 30536     보건복지
# 30537     보건복지
# 30538     보건복지
# 30539     성장동력
#
# [30540 rows x 4 columns]

# %%
laws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30540 entries, 0 to 30539
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CONTENT              30540 non-null  object
#  1   INITIATION DATE      30540 non-null  object
#  2   RELEVANT DEPARTMENT  30540 non-null  object
#  3   CATEGORY             30540 non-null  object
# dtypes: object(4)
# memory usage: 954.5+ KB

# %%
from datetime import datetime
laws['INITIATION DATE']=pd.to_datetime(laws['INITIATION DATE'])
laws.sort_values(by=['INITIATION DATE'],inplace=True)
laws.reset_index(drop=True,inplace=True)
laws
# Out:
# C:\Users\82109\AppData\Local\Temp/ipykernel_30836/4093036992.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laws['INITIATION DATE']=pd.to_datetime(laws['INITIATION DATE'])
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                                     CONTENT INITIATION DATE  \
# 0                             전기사업법 일부개정법률안      2017-08-21
# 1                             공직선거법 일부개정법률안      2017-08-21
# 2                              군인사법 일부개정법률안      2017-08-21
# 3                           조세특례제한법 일부개정법률안      2017-08-21
# 4      환경친화적 자동차의 개발 및 보급 촉진에 관한 법률 일부개정법률안      2017-08-21
# ...                                     ...             ...
# 30535                       산업안전보건법 일부개정법률안      2022-05-06
# 30536          미세먼지 저감 및 관리에 관한 특별법 일부개정법률안      2022-05-06
# 30537                      군사기밀 보호법 일부개정법률안      2022-05-06
# 30538        국가유공자 등 예우 및 지원에 관한 법률 일부개정법률안      2022-05-06
# 30539                           국회법 일부개정법률안      2022-05-06
#
#       RELEVANT DEPARTMENT  CATEGORY
# 0                 산업통상자원부      성장동력
# 1                     법제처      정치개혁
# 2                     국방부  외교/통일/국방
# 3                   기획재정부        행정
# 4                 산업통상자원부      성장동력
# ...                   ...       ...
# 30535               고용노동부       일자리
# 30536                 환경부     안전/환경
# 30537                 국방부  외교/통일/국방
# 30538               국가보훈처      보건복지
# 30539                 법제처      정치개혁
#
# [30540 rows x 4 columns]

# %%
laws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30540 entries, 0 to 30539
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CONTENT              30540 non-null  object
#  1   INITIATION DATE      30540 non-null  datetime64[ns]
#  2   RELEVANT DEPARTMENT  30540 non-null  object
#  3   CATEGORY             30540 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 954.5+ KB

# %%
categoric = laws.groupby('CATEGORY').get_group('정치개혁')
categoric
# Out:
#                                         CONTENT INITIATION DATE  \
# 1                                 공직선거법 일부개정법률안      2017-08-21
# 7                        형의 실효 등에 관한 법률 일부개정법률안      2017-08-21
# 19                               인사청문회법 일부개정법률안      2017-08-21
# 59     사법경찰관리의 직무를 수행할 자와 그 직무범위에 관한 법률 일부개정법률안      2017-08-23
# 66                 아동학대범죄의 처벌 등에 관한 특례법 일부개정법률안      2017-08-24
# ...                                         ...             ...
# 30496                             공직선거법 일부개정법률안      2022-05-02
# 30498                             공직선거법 일부개정법률안      2022-05-03
# 30506                             공직선거법 일부개정법률안      2022-05-03
# 30525                스토킹범죄의 처벌 등에 관한 법률 일부개정법률안      2022-05-06
# 30539                               국회법 일부개정법률안      2022-05-06
#
#       RELEVANT DEPARTMENT CATEGORY
# 1                     법제처     정치개혁
# 7                     법무부     정치개혁
# 19                    법제처     정치개혁
# 59                    법무부     정치개혁
# 66                    법무부     정치개혁
# ...                   ...      ...
# 30496           중앙선거관리위원회     정치개혁
# 30498           중앙선거관리위원회     정치개혁
# 30506           중앙선거관리위원회     정치개혁
# 30525                 법무부     정치개혁
# 30539                 법제처     정치개혁
#
# [3597 rows x 4 columns]

# %%
work_l = categoric.groupby('INITIATION DATE')['CONTENT'].count()
work_l
# Out:
# INITIATION DATE
# 2017-08-21    3
# 2017-08-23    1
# 2017-08-24    1
# 2017-08-25    1
# 2017-08-28    1
#              ..
# 2022-04-27    6
# 2022-04-29    1
# 2022-05-02    2
# 2022-05-03    2
# 2022-05-06    2
# Name: CONTENT, Length: 960, dtype: int64

# %%
work_L = work_l.to_frame()
work_L.columns = ['work_l']
work_L = work_L.rename_axis('date_l').reset_index()
work_L
# Out:
#         date_l  work_l
# 0   2017-08-21       3
# 1   2017-08-23       1
# 2   2017-08-24       1
# 3   2017-08-25       1
# 4   2017-08-28       1
# ..         ...     ...
# 955 2022-04-27       6
# 956 2022-04-29       1
# 957 2022-05-02       2
# 958 2022-05-03       2
# 959 2022-05-06       2
#
# [960 rows x 2 columns]

# %% [markdown]
# # 청원

# %%
petition = pd.read_csv("C:/Users/82109/Documents/GitHub/cla3109_project/finish_petition.csv")
# 데이터의 크기가 어느정도인지 본다.
petition.shape
# Out:
# (161009, 4)

# %%
petition.columns
# Out:
# Index(['category', 'title', 'votes', 'end date'], dtype='object')

# %%
petition
# Out:
#         category                                              title  votes  \
# 0            일자리                                 공정한 기회 균등이 보장되는 사회    144
# 1            일자리                              영어회화전문강사제도는 유지되어야합니다.   1185
# 2            일자리                           공공기관 무조건적인 정규직전환을 반대합니다.     53
# 3          경제민주화                                      소액주주를 보호해주십시오   2137
# 4            일자리                              영어회화전문강사제도는 유지되어야합니다.     17
# ...          ...                                                ...    ...
# 161004        기타                                    화물연대의 갑질을 막아주세요    413
# 161005  외교/통일/국방                              해병대 훈련소에서 쫒겨난 훈련병 이야기    213
# 161006    인권/성평등  가슴에 물혹이 40개 있습니다. 아픈몸으로 성추행을 당했고 상간녀누명을 씌운 성추행...   2129
# 161007        행정                       실내외 마스크 착용 의무화를 해제할 것을 촉구합니다   2086
# 161008      보건복지                    코로나와 백신에 대한 정확한진실과 정직한언론을 촉구합니다    387
#
#           end date
# 0       2017-08-26
# 1       2017-08-26
# 2       2017-08-26
# 3       2017-08-26
# 4       2017-08-26
# ...            ...
# 161004  2022-05-05
# 161005  2022-05-05
# 161006  2022-05-05
# 161007  2022-05-05
# 161008  2022-05-05
#
# [161009 rows x 4 columns]

# %%
categorical = petition.groupby('category').get_group('정치개혁')
categorical
# Out:
#        category                                              title   votes  \
# 51         정치개혁                                          한번만 도와주세요      12
# 89         정치개혁                                     청소년보호법 폐지해야합니다     312
# 95         정치개혁                           정현백 여가부 장관 경질을 강력 청원합니다.      39
# 175        정치개혁                 반국가·반사회·반종교는 누구인지 진실을 가려 주시기 바랍니다.   27387
# 230        정치개혁                           생존권 위협하는 집합건물법 개정이 필요합니다      38
# ...         ...                                                ...     ...
# 160950     정치개혁                                     윤석열 대통령님 응원합니다     995
# 160952     정치개혁  시대착오적인 여성가족부 폐지확정 공약 철회 없이 그대로 가주세요 반드시 여성가족부 ...    1326
# 160955     정치개혁                   윤석열 총장 당시 검찰 특활비 147억  공개 청원합니다.  172010
# 160979     정치개혁                                  *** 휴대폰 포렌식 진행하시오   22306
# 160990     정치개혁                              자랑스런 대한민국 국민이 되고 싶습니다     296
#
#           end date
# 51      2017-09-06
# 89      2017-09-11
# 95      2017-09-13
# 175     2017-09-19
# 230     2017-09-23
# ...            ...
# 160950  2022-04-29
# 160952  2022-04-30
# 160955  2022-04-30
# 160979  2022-05-04
# 160990  2022-05-04
#
# [26569 rows x 4 columns]

# %%
work = categorical.groupby('end date')['title'].count()
work
# Out:
# end date
# 2017-09-06    1
# 2017-09-11    1
# 2017-09-13    1
# 2017-09-19    1
# 2017-09-23    2
#              ..
# 2022-04-24    3
# 2022-04-27    5
# 2022-04-29    1
# 2022-04-30    2
# 2022-05-04    2
# Name: title, Length: 1111, dtype: int64

# %%
petition_c = work.to_frame()
petition_c.columns = ['work_p']
petition_c = petition_c.rename_axis('date_p').reset_index()
petition_c
# Out:
#           date_p  work_p
# 0     2017-09-06       1
# 1     2017-09-11       1
# 2     2017-09-13       1
# 3     2017-09-19       1
# 4     2017-09-23       2
# ...          ...     ...
# 1106  2022-04-24       3
# 1107  2022-04-27       5
# 1108  2022-04-29       1
# 1109  2022-04-30       2
# 1110  2022-05-04       2
#
# [1111 rows x 2 columns]

# %%
petition_c.info()  # date_p가 다시 object가 됨ㅠ
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111 entries, 0 to 1110
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date_p  1111 non-null   object
#  1   work_p  1111 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 17.5+ KB

# %%
petition_c['date_p']=pd.to_datetime(petition_c['date_p'])

# %% [markdown]
# # 시각화

# %%
from matplotlib import pyplot as plt
from matplotlib import rc
import matplotlib.font_manager as fm

# 디렉토리 및 파일 이름에 맞추어 변경
font_location = "C:/Users/82109/Documents/Jupyter/한국어인공지능 프젝/NanumGothic.ttf"

font_name = fm.FontProperties(fname=font_location).get_name()
rc('font', family=font_name)
plt.rcParams["figure.figsize"] = [20,8]

plt.rc('font', size=20)        # 기본 폰트 크기
# plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
# plt.rc('xtick', labelsize=50)  # x축 눈금 폰트 크기 
# plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
# plt.rc('legend', fontsize=20)  # 범례 폰트 크기
# plt.rc('figure', titlesize=50) # figure title 폰트 크기

# %%
fig, ax1 = plt.subplots()

ax1.plot(petition_c.groupby(pd.Grouper(key='date_p',freq='1M')).sum(), label='Petition',color = 'b')

ax2 = ax1.twinx()
ax2.plot(work_L.groupby(pd.Grouper(key='date_l',freq='1M')).sum(), label='Law',color = 'g')

plt.title('정치개혁')
ax1.set_ylabel('petition_count')
ax2.set_ylabel('law_count')

ax1.legend(bbox_to_anchor=(1,1))
ax2.legend(bbox_to_anchor=(1,0.9))

# %% [markdown]
# # 회귀

# %%
petition_m = petition_c.groupby(pd.Grouper(key='date_p',freq='1Y')).sum()
petition_m.reset_index(level=0, inplace=True)
petition_m.rename(columns = {'date_p' : 'date'}, inplace = True)
petition_m
# Out:
#         date  work_p
# 0 2017-12-31     421
# 1 2018-12-31   18635
# 2 2019-12-31    6267
# 3 2020-12-31     601
# 4 2021-12-31     489
# 5 2022-12-31     156

# %%
law_m = work_L.groupby(pd.Grouper(key='date_l',freq='1Y')).sum()
law_m.reset_index(level=0, inplace=True)
law_m.rename(columns = {'date_l' : 'date'}, inplace = True)
law_m
# Out:
#         date  work_l
# 0 2017-12-31     220
# 1 2018-12-31     642
# 2 2019-12-31     680
# 3 2020-12-31     968
# 4 2021-12-31     864
# 5 2022-12-31     223

# %%
petition_law_join = pd.merge(petition_m,law_m,on='date',how='inner')
petition_law_join
# Out:
#         date  work_p  work_l
# 0 2017-12-31     421     220
# 1 2018-12-31   18635     642
# 2 2019-12-31    6267     680
# 3 2020-12-31     601     968
# 4 2021-12-31     489     864
# 5 2022-12-31     156     223

# %%
plt.scatter(petition_law_join['work_p'],petition_law_join['work_l'])

# %%
import statsmodels.api as sm 
model = sm.OLS.from_formula("work_l ~ work_p", data = petition_law_join)
result = model.fit()
result.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 work_l   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.231
# Method:                 Least Squares   F-statistic:                   0.06151
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):              0.816
# Time:                        14:21:37   Log-Likelihood:                -42.459
# No. Observations:                   6   AIC:                             88.92
# Df Residuals:                       4   BIC:                             88.50
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    576.0399    171.632      3.356      0.028      99.512    1052.567
# work_p         0.0053      0.021      0.248      0.816      -0.054       0.065
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.294
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.546
# Skew:                          -0.057   Prob(JB):                        0.761
# Kurtosis:                       1.527   Cond. No.                     9.63e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.63e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # 추가 분석

# %%
#기간 나누기 2019-08-01~
pd.options.display.max_rows = 60
second_laws = laws.iloc[12591:,:]
second_laws
# Out:
#                                 CONTENT INITIATION DATE RELEVANT DEPARTMENT  \
# 12591                     근로기준법 일부개정법률안      2019-08-01               고용노동부
# 12592                     담배사업법 일부개정법률안      2019-08-01               기획재정부
# 12593  원자력안전위원회의 설치 및 운영에 관한 법률 일부개정법률안      2019-08-01            원자력안전위원회
# 12594                    원자력안전법 일부개정법률안      2019-08-01            원자력안전위원회
# 12595                     관광진흥법 일부개정법률안      2019-08-01             문화체육관광부
# ...                                 ...             ...                 ...
# 30535        스토킹범죄의 처벌 등에 관한 법률 일부개정법률안      2022-05-06                 법무부
# 30536                     정부조직법 일부개정법률안      2022-05-06               행정안전부
# 30537    국가유공자 등 예우 및 지원에 관한 법률 일부개정법률안      2022-05-06               국가보훈처
# 30538               화물자동차 운수사업법 일부개정법률안      2022-05-06               국토교통부
# 30539                       국회법 일부개정법률안      2022-05-06                 법제처
#
#           CATEGORY
# 12591          일자리
# 12592           행정
# 12593        안전/환경
# 12594        안전/환경
# 12595  문화/예술/체육/언론
# ...            ...
# 30535         정치개혁
# 30536           행정
# 30537         보건복지
# 30538     교통/건축/국토
# 30539         정치개혁
#
# [17949 rows x 4 columns]

# %%
second_laws.to_csv('./second_laws.csv', index = None)

# %%
second_petition = petition.iloc[137959:,:]
second_petition
# Out:
#         category                                              title  votes  \
# 137959     경제민주화                             공익사업용 토지에 대한 양도세 감면 청원    290
# 137960     경제민주화       ******(구, *****)  대표 및 관련자들을 강력히 처벌해 주십시요!!!    149
# 137961     안전/환경               서울시장 박원순을 직권남용으로 인한 직위해제를 강력히 청원합니다.   5008
# 137962      보건복지                             화상 환자분들도  장애인 등록해주세요`~    502
# 137963  외교/통일/국방           정부, 우리 기업에 대한 中 갑질횡포에 적극 대응하고 도움이 필요합니다!   1305
# ...          ...                                                ...    ...
# 161004        기타                                    화물연대의 갑질을 막아주세요    413
# 161005  외교/통일/국방                              해병대 훈련소에서 쫒겨난 훈련병 이야기    213
# 161006    인권/성평등  가슴에 물혹이 40개 있습니다. 아픈몸으로 성추행을 당했고 상간녀누명을 씌운 성추행...   2129
# 161007        행정                       실내외 마스크 착용 의무화를 해제할 것을 촉구합니다   2086
# 161008      보건복지                    코로나와 백신에 대한 정확한진실과 정직한언론을 촉구합니다    387
#
#           end date
# 137959  2019-08-01
# 137960  2019-08-01
# 137961  2019-08-01
# 137962  2019-08-01
# 137963  2019-08-01
# ...            ...
# 161004  2022-05-05
# 161005  2022-05-05
# 161006  2022-05-05
# 161007  2022-05-05
# 161008  2022-05-05
#
# [23050 rows x 4 columns]

# %%
second_petition.to_csv('./second_petition.csv', index = None)

# %% [markdown]
# # 전체로 해보자

# %%
work_l = laws.groupby('INITIATION DATE')['CONTENT'].count()
work_L = work_l.to_frame()
work_L.columns = ['work_l']
work_L = work_L.rename_axis('date_l').reset_index()
work_L.iloc[3:,:]
# Out:
#          date_l  work_l
# 3    2017-08-24      11
# 4    2017-08-25      38
# 5    2017-08-28     101
# 6    2017-08-29      33
# 7    2017-08-30      30
# ...         ...     ...
# 1134 2022-04-29      16
# 1135 2022-05-02       6
# 1136 2022-05-03      11
# 1137 2022-05-04      16
# 1138 2022-05-06      16
#
# [1136 rows x 2 columns]

# %%
work = petition.groupby('end date')['title'].count()
petition_c = work.to_frame()
petition_c.columns = ['work_p']
petition_c = petition_c.rename_axis('date_p').reset_index()
petition_c
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1375 entries, 0 to 1374
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date_p  1375 non-null   object
#  1   work_p  1375 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 21.6+ KB

# %%
work_L.groupby(pd.Grouper(key='date_l',freq='1M')).sum()
# Out:
#             work_l
# date_l
# 2017-08-31     309
# 2017-09-30     834
# 2017-10-31     138
# 2017-11-30     544
# 2017-12-31     591
# 2018-01-31     495
# 2018-02-28     526
# 2018-03-31     520
# 2018-04-30     511
# 2018-05-31     493
# 2018-06-30     268
# 2018-07-31     534
# 2018-08-31     519
# 2018-09-30     516
# 2018-10-31     427
# 2018-11-30     717
# 2018-12-31     976
# 2019-01-31     474
# 2019-02-28     439
# 2019-03-31     526
# 2019-04-30     570
# 2019-05-31     668
# 2019-06-30     434
# 2019-07-31     562
# 2019-08-31     471
# 2019-09-30     446
# 2019-10-31     732
# 2019-11-30     554
# 2019-12-31     321
# 2020-01-31     106
# 2020-02-29      66
# 2020-03-31     150
# 2020-04-30      70
# 2020-05-31      59
# 2020-06-30    1167
# 2020-07-31    1338
# 2020-08-31     738
# 2020-09-30     966
# 2020-10-31     400
# 2020-11-30    1134
# 2020-12-31    1170
# 2021-01-31     650
# 2021-02-28     615
# 2021-03-31     788
# 2021-04-30     592
# 2021-05-31     612
# 2021-06-30     735
# 2021-07-31     581
# 2021-08-31     468
# 2021-09-30     371
# 2021-10-31     271
# 2021-11-30     556
# 2021-12-31     606
# 2022-01-31     382
# 2022-02-28     190
# 2022-03-31     196
# 2022-04-30     399
# 2022-05-31      49

# %%
petition_c['date_p']=pd.to_datetime(petition_c['date_p'])
petition_c.groupby(pd.Grouper(key='date_p',freq='1M')).sum()
# Out:
#             work_p
# date_p
# 2017-08-31      18
# 2017-09-30     291
# 2017-10-31     652
# 2017-11-30     740
# 2017-12-31    2591
# 2018-01-31    3550
# 2018-02-28    6519
# 2018-03-31    9130
# 2018-04-30    5960
# 2018-05-31    9798
# 2018-06-30    9523
# 2018-07-31    8858
# 2018-08-31   11985
# 2018-09-30   11785
# 2018-10-31   10108
# 2018-11-30   12307
# 2018-12-31   10451
# 2019-01-31    7276
# 2019-02-28    2119
# 2019-03-31    5358
# 2019-04-30    7147
# 2019-05-31     505
# 2019-06-30     688
# 2019-07-31     600
# 2019-08-31     572
# 2019-09-30     618
# 2019-10-31     520
# 2019-11-30     399
# 2019-12-31     429
# 2020-01-31     448
# 2020-02-29     378
# 2020-03-31    1167
# 2020-04-30    1588
# 2020-05-31     896
# 2020-06-30     825
# 2020-07-31     892
# 2020-08-31    1026
# 2020-09-30     873
# 2020-10-31     886
# 2020-11-30     535
# 2020-12-31     594
# 2021-01-31     847
# 2021-02-28     857
# 2021-03-31     552
# 2021-04-30     520
# 2021-05-31     662
# 2021-06-30     708
# 2021-07-31     734
# 2021-08-31     720
# 2021-09-30     727
# 2021-10-31     558
# 2021-11-30     503
# 2021-12-31     608
# 2022-01-31     816
# 2022-02-28     595
# 2022-03-31     446
# 2022-04-30     510
# 2022-05-31      41

# %%
fig, ax1 = plt.subplots()

ax1.plot(petition_c.groupby(pd.Grouper(key='date_p',freq='1M')).sum(), label='Petition',color = 'b')

ax2 = ax1.twinx()
ax2.plot(work_L.groupby(pd.Grouper(key='date_l',freq='1M')).sum(), label='Law',color = 'g')

plt.title('전체')
ax1.set_ylabel('petition_count')
ax2.set_ylabel('law_count')

ax1.legend(bbox_to_anchor=(1,1))
ax2.legend(bbox_to_anchor=(1,0.9))

# %%
#전체 회귀돌리기
petition_m = petition_c.groupby(pd.Grouper(key='date_p',freq='1M')).sum()
petition_m.reset_index(level=0, inplace=True)
petition_m.rename(columns = {'date_p' : 'date'}, inplace = True)
petition_m
# Out:
#          date  work_p
# 0  2017-08-31      18
# 1  2017-09-30     291
# 2  2017-10-31     652
# 3  2017-11-30     740
# 4  2017-12-31    2591
# 5  2018-01-31    3550
# 6  2018-02-28    6519
# 7  2018-03-31    9130
# 8  2018-04-30    5960
# 9  2018-05-31    9798
# 10 2018-06-30    9523
# 11 2018-07-31    8858
# 12 2018-08-31   11985
# 13 2018-09-30   11785
# 14 2018-10-31   10108
# 15 2018-11-30   12307
# 16 2018-12-31   10451
# 17 2019-01-31    7276
# 18 2019-02-28    2119
# 19 2019-03-31    5358
# 20 2019-04-30    7147
# 21 2019-05-31     505
# 22 2019-06-30     688
# 23 2019-07-31     600
# 24 2019-08-31     572
# 25 2019-09-30     618
# 26 2019-10-31     520
# 27 2019-11-30     399
# 28 2019-12-31     429
# 29 2020-01-31     448
# 30 2020-02-29     378
# 31 2020-03-31    1167
# 32 2020-04-30    1588
# 33 2020-05-31     896
# 34 2020-06-30     825
# 35 2020-07-31     892
# 36 2020-08-31    1026
# 37 2020-09-30     873
# 38 2020-10-31     886
# 39 2020-11-30     535
# 40 2020-12-31     594
# 41 2021-01-31     847
# 42 2021-02-28     857
# 43 2021-03-31     552
# 44 2021-04-30     520
# 45 2021-05-31     662
# 46 2021-06-30     708
# 47 2021-07-31     734
# 48 2021-08-31     720
# 49 2021-09-30     727
# 50 2021-10-31     558
# 51 2021-11-30     503
# 52 2021-12-31     608
# 53 2022-01-31     816
# 54 2022-02-28     595
# 55 2022-03-31     446
# 56 2022-04-30     510
# 57 2022-05-31      41

# %%
law_m = work_L.groupby(pd.Grouper(key='date_l',freq='1M')).sum()
law_m.reset_index(level=0, inplace=True)
law_m.rename(columns = {'date_l' : 'date'}, inplace = True)
law_m
# Out:
#          date  work_l
# 0  2017-08-31     309
# 1  2017-09-30     834
# 2  2017-10-31     138
# 3  2017-11-30     544
# 4  2017-12-31     591
# 5  2018-01-31     495
# 6  2018-02-28     526
# 7  2018-03-31     520
# 8  2018-04-30     511
# 9  2018-05-31     493
# 10 2018-06-30     268
# 11 2018-07-31     534
# 12 2018-08-31     519
# 13 2018-09-30     516
# 14 2018-10-31     427
# 15 2018-11-30     717
# 16 2018-12-31     976
# 17 2019-01-31     474
# 18 2019-02-28     439
# 19 2019-03-31     526
# 20 2019-04-30     570
# 21 2019-05-31     668
# 22 2019-06-30     434
# 23 2019-07-31     562
# 24 2019-08-31     471
# 25 2019-09-30     446
# 26 2019-10-31     732
# 27 2019-11-30     554
# 28 2019-12-31     321
# 29 2020-01-31     106
# 30 2020-02-29      66
# 31 2020-03-31     150
# 32 2020-04-30      70
# 33 2020-05-31      59
# 34 2020-06-30    1167
# 35 2020-07-31    1338
# 36 2020-08-31     738
# 37 2020-09-30     966
# 38 2020-10-31     400
# 39 2020-11-30    1134
# 40 2020-12-31    1170
# 41 2021-01-31     650
# 42 2021-02-28     615
# 43 2021-03-31     788
# 44 2021-04-30     592
# 45 2021-05-31     612
# 46 2021-06-30     735
# 47 2021-07-31     581
# 48 2021-08-31     468
# 49 2021-09-30     371
# 50 2021-10-31     271
# 51 2021-11-30     556
# 52 2021-12-31     606
# 53 2022-01-31     382
# 54 2022-02-28     190
# 55 2022-03-31     196
# 56 2022-04-30     399
# 57 2022-05-31      49

# %%
petition_law_join = pd.merge(petition_m,law_m,on='date',how='inner')
petition_law_join
# Out:
#          date  work_p  work_l
# 0  2017-08-31      18     309
# 1  2017-09-30     291     834
# 2  2017-10-31     652     138
# 3  2017-11-30     740     544
# 4  2017-12-31    2591     591
# 5  2018-01-31    3550     495
# 6  2018-02-28    6519     526
# 7  2018-03-31    9130     520
# 8  2018-04-30    5960     511
# 9  2018-05-31    9798     493
# 10 2018-06-30    9523     268
# 11 2018-07-31    8858     534
# 12 2018-08-31   11985     519
# 13 2018-09-30   11785     516
# 14 2018-10-31   10108     427
# 15 2018-11-30   12307     717
# 16 2018-12-31   10451     976
# 17 2019-01-31    7276     474
# 18 2019-02-28    2119     439
# 19 2019-03-31    5358     526
# 20 2019-04-30    7147     570
# 21 2019-05-31     505     668
# 22 2019-06-30     688     434
# 23 2019-07-31     600     562
# 24 2019-08-31     572     471
# 25 2019-09-30     618     446
# 26 2019-10-31     520     732
# 27 2019-11-30     399     554
# 28 2019-12-31     429     321
# 29 2020-01-31     448     106
# 30 2020-02-29     378      66
# 31 2020-03-31    1167     150
# 32 2020-04-30    1588      70
# 33 2020-05-31     896      59
# 34 2020-06-30     825    1167
# 35 2020-07-31     892    1338
# 36 2020-08-31    1026     738
# 37 2020-09-30     873     966
# 38 2020-10-31     886     400
# 39 2020-11-30     535    1134
# 40 2020-12-31     594    1170
# 41 2021-01-31     847     650
# 42 2021-02-28     857     615
# 43 2021-03-31     552     788
# 44 2021-04-30     520     592
# 45 2021-05-31     662     612
# 46 2021-06-30     708     735
# 47 2021-07-31     734     581
# 48 2021-08-31     720     468
# 49 2021-09-30     727     371
# 50 2021-10-31     558     271
# 51 2021-11-30     503     556
# 52 2021-12-31     608     606
# 53 2022-01-31     816     382
# 54 2022-02-28     595     190
# 55 2022-03-31     446     196
# 56 2022-04-30     510     399
# 57 2022-05-31      41      49

# %%
plt.scatter(petition_law_join['work_p'],petition_law_join['work_l'])

# %%
import statsmodels.api as sm 
model = sm.OLS.from_formula("work_l ~ work_p", data = petition_law_join)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 work_l   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                    0.1272
# Date:                Thu, 02 Jun 2022   Prob (F-statistic):              0.723
# Time:                        15:47:30   Log-Likelihood:                -409.08
# No. Observations:                  58   AIC:                             822.2
# Df Residuals:                      56   BIC:                             826.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    516.5943     46.670     11.069      0.000     423.102     610.087
# work_p         0.0036      0.010      0.357      0.723      -0.017       0.024
# ==============================================================================
# Omnibus:                        6.924   Durbin-Watson:                   1.116
# Prob(Omnibus):                  0.031   Jarque-Bera (JB):                5.991
# Skew:                           0.699   Prob(JB):                       0.0500
# Kurtosis:                       3.725   Cond. No.                     5.79e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.79e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
